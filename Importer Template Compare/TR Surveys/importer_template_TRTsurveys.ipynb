# %% [markdown]
# ## Compare TR Survey NIS Importer Template with Country Template

# %% [markdown]
# ### Set Up Requirements

# %%
pip install -r requirements.txt
# Out:
# Requirement already satisfied: numpy in c:\users\ebradfield\appdata\local\programs\python\python312\lib\site-packages (from -r requirements.txt (line 1)) (1.26.4)
# Requirement already satisfied: pandas in c:\users\ebradfield\appdata\local\programs\python\python312\lib\site-packages (from -r requirements.txt (line 2)) (2.2.2)
# Requirement already satisfied: openpyxl in c:\users\ebradfield\appdata\local\programs\python\python312\lib\site-packages (from -r requirements.txt (line 3)) (3.1.5)
# Requirement already satisfied: datacompy in c:\users\ebradfield\appdata\local\programs\python\python312\lib\site-packages (from -r requirements.txt (line 4)) (0.13.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ebradfield\appdata\roaming\python\python312\site-packages (from pandas->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ebradfield\appdata\local\programs\python\python312\lib\site-packages (from pandas->-r requirements.txt (line 2)) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ebradfield\appdata\local\programs\python\python312\lib\site-packages (from pandas->-r requirements.txt (line 2)) (2024.2)
# Requirement already satisfied: et-xmlfile in c:\users\ebradfield\appdata\local\programs\python\python312\lib\site-packages (from openpyxl->-r requirements.txt (line 3)) (1.1.0)
# Requirement already satisfied: ordered-set<=4.1.0,>=4.0.2 in c:\users\ebradfield\appdata\local\programs\python\python312\lib\site-packages (from datacompy->-r requirements.txt (line 4)) (4.1.0)
# Requirement already satisfied: fugue<=0.9.1,>=0.8.7 in c:\users\ebradfield\appdata\local\programs\python\python312\lib\site-packages (from datacompy->-r requirements.txt (line 4)) (0.9.1)
# Requirement already satisfied: polars<=1.7.0,>=0.20.4 in c:\users\ebradfield\appdata\local\programs\python\python312\lib\site-packages (from datacompy->-r requirements.txt (line 4)) (1.6.0)
# Requirement already satisfied: triad>=0.9.7 in c:\users\ebradfield\appdata\local\programs\python\python312\lib\site-packages (from fugue<=0.9.1,>=0.8.7->datacompy->-r requirements.txt (line 4)) (0.9.8)
# Requirement already satisfied: adagio>=0.2.4 in c:\users\ebradfield\appdata\local\programs\python\python312\lib\site-packages (from fugue<=0.9.1,>=0.8.7->datacompy->-r requirements.txt (line 4)) (0.2.6)
# Requirement already satisfied: six>=1.5 in c:\users\ebradfield\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: pyarrow>=6.0.1 in c:\users\ebradfield\appdata\local\programs\python\python312\lib\site-packages (from triad>=0.9.7->fugue<=0.9.1,>=0.8.7->datacompy->-r requirements.txt (line 4)) (17.0.0)
# Requirement already satisfied: fsspec>=2022.5.0 in c:\users\ebradfield\appdata\local\programs\python\python312\lib\site-packages (from triad>=0.9.7->fugue<=0.9.1,>=0.8.7->datacompy->-r requirements.txt (line 4)) (2024.9.0)
# Requirement already satisfied: fs in c:\users\ebradfield\appdata\local\programs\python\python312\lib\site-packages (from triad>=0.9.7->fugue<=0.9.1,>=0.8.7->datacompy->-r requirements.txt (line 4)) (2.4.16)
# Requirement already satisfied: appdirs~=1.4.3 in c:\users\ebradfield\appdata\local\programs\python\python312\lib\site-packages (from fs->triad>=0.9.7->fugue<=0.9.1,>=0.8.7->datacompy->-r requirements.txt (line 4)) (1.4.4)
# Requirement already satisfied: setuptools in c:\users\ebradfield\appdata\local\programs\python\python312\lib\site-packages (from fs->triad>=0.9.7->fugue<=0.9.1,>=0.8.7->datacompy->-r requirements.txt (line 4)) (75.1.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Set up Macros and Packages

# %%
nis_download = r"C:\Users\ebradfield\OneDrive - Research Triangle Institute\Act East\NIS\Importer File Compare\sample data\TRT- Trachoma Survey Tracker_fromNIS.xlsx"
country_download = r"C:\Users\ebradfield\OneDrive - Research Triangle Institute\Act East\NIS\Importer File Compare\sample data\TRT- Trachoma Survey Tracker_fromcountry.xlsx"
summary_output_EU_uid = r"C:\Users\ebradfield\OneDrive - Research Triangle Institute\Act East\NIS\Importer File Compare\sample data\TR_summary_output_EU_uid.txt"
summary_output_EU_FY = r"C:\Users\ebradfield\OneDrive - Research Triangle Institute\Act East\NIS\Importer File Compare\sample data\TR_summary_output_EU_FY.txt"
additions_deletions = r"C:\Users\ebradfield\OneDrive - Research Triangle Institute\Act East\NIS\Importer File Compare\sample data\TR_additions_deletions.xlsx"

import pandas as pd
import datacompy
# Out:
# C:\Users\ebradfield\AppData\Local\Temp\ipykernel_29176\58688614.py:8: UserWarning: Python 3.12 and above currently is not supported by Spark and Ray. Please note that some functionality will not work and currently is not supported.
#   import datacompy

# %% [markdown]
# ### Read in Recently Downloaded Importer Template

# %%
from_nis = pd.read_excel(io=f'{nis_download}', sheet_name ="Data", skiprows = 1)
from_nis.columns.values[0] = "Event UID"
from_nis.columns.values[1] = 'Organisation Unit*'
from_nis.columns.values[2] = 'EU-TR Evaluation Unit - Trachoma*'
from_nis.columns.values[3] = 'TRT Survey Date *'
from_nis.columns.values[4] = 'Latitude'
from_nis.columns.values[5] = 'Longitude'
from_nis.columns.values[6] = 'Status'
from_nis.drop(0, inplace=True)
print(from_nis)
# Out:
#        Event UID Organisation Unit* EU-TR Evaluation Unit - Trachoma*  \
# 1    CrizV3ZgYa5           Ethiopia         ET-TR-EU-281702-Bule Hora
# 2    D9sqRdrAuyP           Ethiopia            ET-TR-EU-469670-Wonchi
# 3    DzAqMlzGXSb           Ethiopia      ET-TR-EU-072067-Kercha Rural
# 4    EEFizhaNLKi           Ethiopia             ET-TR-EU-717678-Abaya
# 5    FZj9hso9Qte           Ethiopia              ET-TR-EU-527621-Mulo
# ..           ...                ...                               ...
# 98   VJclO9IOgqu           Ethiopia            ET-TR-EU-379840-Jikawo
# 99   nTnlhMRfLHE           Ethiopia             ET-TR-EU-441801-Itang
# 100  rBB3ChacVnS           Ethiopia          ET-TR-EU-495476-Wanthuwa
# 101  y4HvKGz6ppD           Ethiopia             ET-TR-EU-244773-Makoy
# 102  zI9VNaSfLSS           Ethiopia              ET-TR-EU-223442-Lare
#
#     TRT Survey Date * Latitude Longitude     Status Review status  \
# 1          2023-10-01      NaN       NaN  COMPLETED      Reviewed
# 2          2023-10-01      NaN       NaN  COMPLETED      Reviewed
# 3          2023-10-01      NaN       NaN  COMPLETED      Reviewed
# 4          2023-10-01      NaN       NaN  COMPLETED      Reviewed
# 5          2023-10-01      NaN       NaN  COMPLETED      Reviewed
# ..                ...      ...       ...        ...           ...
# 98         2024-08-25      NaN       NaN  COMPLETED      Reviewed
# 99         2024-08-25      NaN       NaN  COMPLETED      Reviewed
# 100        2024-08-25      NaN       NaN  COMPLETED      Reviewed
# 101        2024-08-25      NaN       NaN  COMPLETED      Reviewed
# 102        2024-08-25      NaN       NaN  COMPLETED      Reviewed
#
#     Tropical Data ID Type of survey*  ... TT surgery action  \
# 1                NaN             TIS  ...               NaN
# 2                NaN             TIS  ...               NaN
# 3                NaN             TIS  ...               NaN
# 4                NaN             TIS  ...               NaN
# 5                NaN             TIS  ...               NaN
# ..               ...             ...  ...               ...
# 98               NaN             TIS  ...               NaN
# 99               NaN             TIS  ...               NaN
# 100              NaN             TIS  ...               NaN
# 101              NaN             TIS  ...               NaN
# 102              NaN             TIS  ...               NaN
#
#     Is 'Survey description' missing?  \
# 1                              false
# 2                              false
# 3                              false
# 4                              false
# 5                              false
# ..                               ...
# 98                             false
# 99                             false
# 100                            false
# 101                            false
# 102                            false
#
#     Is Justification missing if the survey was postponed or canceled?  \
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# ..                                                 ...
# 98                                                 NaN
# 99                                                 NaN
# 100                                                NaN
# 101                                                NaN
# 102                                                NaN
#
#     Is 'Budget year (FY)' missing? Is 'Eligible survey date' missing?  \
# 1                            false                               true
# 2                            false                               true
# 3                            false                               true
# 4                            false                               true
# 5                            false                               true
# ..                             ...                                ...
# 98                           false                               true
# 99                           false                               true
# 100                          false                               true
# 101                          false                               true
# 102                          false                               true
#
#     Is 'Original planned date' missing? Is 'Funding source' missing?  \
# 1                                 false                        false
# 2                                 false                        false
# 3                                 false                        false
# 4                                 false                        false
# 5                                 false                        false
# ..                                  ...                          ...
# 98                                false                        false
# 99                                false                        false
# 100                               false                        false
# 101                               false                        false
# 102                               false                        false
#
#     Is 'EU population' missing? Is 'Survey TF result (%)' missing?  \
# 1                          true                                NaN
# 2                           NaN                                NaN
# 3                          true                                NaN
# 4                          true                                NaN
# 5                           NaN                                NaN
# ..                          ...                                ...
# 98                          NaN                                NaN
# 99                         true                                NaN
# 100                         NaN                                NaN
# 101                         NaN                                NaN
# 102                        true                                NaN
#
#     Is 'Survey TT result (%)' missing?
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# 5                                  NaN
# ..                                 ...
# 98                                 NaN
# 99                                 NaN
# 100                                NaN
# 101                                NaN
# 102                                NaN
#
# [102 rows x 73 columns]
# c:\Users\ebradfield\AppData\Local\Programs\Python\Python312\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)

# %% [markdown]
# ### Generate Summary of Recently Downloaded Importer Template

# %%
from_nis.nunique(axis=0, dropna=True)
# Out:
# Event UID                              102
# Organisation Unit*                       1
# EU-TR Evaluation Unit - Trachoma*      102
# TRT Survey Date *                       48
# Latitude                                 0
#                                       ...
# Is 'Original planned date' missing?      1
# Is 'Funding source' missing?             1
# Is 'EU population' missing?              2
# Is 'Survey TF result (%)' missing?       1
# Is 'Survey TT result (%)' missing?       1
# Length: 73, dtype: int64

# %% [markdown]
# ### Read in Template from Country Team

# %%
from_country = pd.read_excel(io=f'{country_download}', sheet_name ="Data", skiprows = 1)
from_country.columns.values[0] = "Event UID"
from_country.columns.values[1] = 'Organisation Unit*'
from_country.columns.values[2] = 'EU-TR Evaluation Unit - Trachoma*'
from_country.columns.values[3] = 'LFT Survey Date *'
from_country.columns.values[4] = 'Latitude'
from_country.columns.values[5] = 'Longitude'
from_country.columns.values[6] = 'Status'
from_country.drop(0, inplace=True)
print(from_country)
# Out:
#        Event UID Organisation Unit* EU-TR Evaluation Unit - Trachoma*  \
# 1    CrizV3ZgYa5           Ethiopia         ET-TR-EU-281702-Bule Hora
# 2    D9sqRdrAuyP           Ethiopia            ET-TR-EU-469670-Wonchi
# 3    DzAqMlzGXSb           Ethiopia      ET-TR-EU-072067-Kercha Rural
# 4    EEFizhaNLKi           Ethiopia             ET-TR-EU-717678-Abaya
# 5    FZj9hso9Qte           Ethiopia              ET-TR-EU-527621-Mulo
# ..           ...                ...                               ...
# 98   VJclO9IOgqu           Ethiopia            ET-TR-EU-379840-Jikawo
# 99   nTnlhMRfLHE           Ethiopia             ET-TR-EU-441801-Itang
# 100  rBB3ChacVnS           Ethiopia          ET-TR-EU-495476-Wanthuwa
# 101  y4HvKGz6ppD           Ethiopia             ET-TR-EU-244773-Makoy
# 102  zI9VNaSfLSS           Ethiopia              ET-TR-EU-223442-Lare
#
#     LFT Survey Date * Latitude Longitude     Status Review status  \
# 1          2023-10-01      NaN       NaN  COMPLETED      Reviewed
# 2          2023-10-01      NaN       NaN  COMPLETED      Reviewed
# 3          2023-10-01      NaN       NaN  COMPLETED      Reviewed
# 4          2023-10-01      NaN       NaN  COMPLETED      Reviewed
# 5          2023-10-01      NaN       NaN  COMPLETED      Reviewed
# ..                ...      ...       ...        ...           ...
# 98         2024-08-25      NaN       NaN  COMPLETED      Reviewed
# 99         2024-08-25      NaN       NaN  COMPLETED      Reviewed
# 100        2024-08-25      NaN       NaN  COMPLETED      Reviewed
# 101        2024-08-25      NaN       NaN  COMPLETED      Reviewed
# 102        2024-08-25      NaN       NaN  COMPLETED      Reviewed
#
#     Tropical Data ID Type of survey*  ... TT surgery action  \
# 1                NaN             TIS  ...               NaN
# 2                NaN             TIS  ...               NaN
# 3                NaN             TIS  ...               NaN
# 4                NaN             TIS  ...               NaN
# 5                NaN             TIS  ...               NaN
# ..               ...             ...  ...               ...
# 98               NaN             TIS  ...               NaN
# 99               NaN             TIS  ...               NaN
# 100              NaN             TIS  ...               NaN
# 101              NaN             TIS  ...               NaN
# 102              NaN             TIS  ...               NaN
#
#     Is 'Survey description' missing?  \
# 1                              false
# 2                              false
# 3                              false
# 4                              false
# 5                              false
# ..                               ...
# 98                             false
# 99                             false
# 100                            false
# 101                            false
# 102                            false
#
#     Is Justification missing if the survey was postponed or canceled?  \
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# ..                                                 ...
# 98                                                 NaN
# 99                                                 NaN
# 100                                                NaN
# 101                                                NaN
# 102                                                NaN
#
#     Is 'Budget year (FY)' missing? Is 'Eligible survey date' missing?  \
# 1                            false                               true
# 2                            false                               true
# 3                            false                               true
# 4                            false                               true
# 5                            false                               true
# ..                             ...                                ...
# 98                           false                               true
# 99                           false                               true
# 100                          false                               true
# 101                          false                               true
# 102                          false                               true
#
#     Is 'Original planned date' missing? Is 'Funding source' missing?  \
# 1                                 false                        false
# 2                                 false                        false
# 3                                 false                        false
# 4                                 false                        false
# 5                                 false                        false
# ..                                  ...                          ...
# 98                                false                        false
# 99                                false                        false
# 100                               false                        false
# 101                               false                        false
# 102                               false                        false
#
#     Is 'EU population' missing? Is 'Survey TF result (%)' missing?  \
# 1                          true                                NaN
# 2                           NaN                                NaN
# 3                          true                                NaN
# 4                          true                                NaN
# 5                           NaN                                NaN
# ..                          ...                                ...
# 98                          NaN                                NaN
# 99                         true                                NaN
# 100                         NaN                                NaN
# 101                         NaN                                NaN
# 102                        true                                NaN
#
#     Is 'Survey TT result (%)' missing?
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# 5                                  NaN
# ..                                 ...
# 98                                 NaN
# 99                                 NaN
# 100                                NaN
# 101                                NaN
# 102                                NaN
#
# [102 rows x 73 columns]
# c:\Users\ebradfield\AppData\Local\Programs\Python\Python312\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)

# %% [markdown]
# ### Generate Summary of Template from Country Team

# %%
from_country.nunique(axis=0, dropna=True)
# Out:
# Event UID                              102
# Organisation Unit*                       1
# EU-TR Evaluation Unit - Trachoma*      102
# LFT Survey Date *                       64
# Latitude                                 0
#                                       ...
# Is 'Original planned date' missing?      1
# Is 'Funding source' missing?             1
# Is 'EU population' missing?              2
# Is 'Survey TF result (%)' missing?       1
# Is 'Survey TT result (%)' missing?       1
# Length: 73, dtype: int64

# %% [markdown]
# ### Merge Dataframes and Identify Discrepancies

# %%
#Will identify changes to records based on unique combination of EU and UID; will identify if any new EU/UID combinations have been added 
compare_EU_uid = datacompy.Compare(from_nis, from_country, join_columns=['EU-TR Evaluation Unit - Trachoma*','Event UID'], df1_name='from_nis',
    df2_name='from_country')

#Will identify if any EUs have changed their UIDs
compare_EU_FY = datacompy.Compare(from_nis, from_country, join_columns=['EU-TR Evaluation Unit - Trachoma*','FY'], df1_name='from_nis',
    df2_name='from_country')

print(compare_EU_uid.report(sample_count=1000000))
print(compare_EU_FY.report(sample_count=1000000))
# Out:
# DataComPy Comparison
# --------------------
#
# DataFrame Summary
# -----------------
#
#       DataFrame  Columns  Rows
# 0      from_nis       73   102
# 1  from_country       73   102
#
# Column Summary
# --------------
#
# Number of columns in common: 72
# Number of columns in from_nis but not in from_country: 1
# Number of columns in from_country but not in from_nis: 1
#
# Row Summary
# -----------
#
# Matched on: eu-tr evaluation unit - trachoma*, event uid
# Any duplicates on match values: No
# Absolute Tolerance: 0
# Relative Tolerance: 0
# Number of rows in common: 102
# Number of rows in from_nis but not in from_country: 0
# Number of rows in from_country but not in from_nis: 0
#
# Number of rows with some compared columns unequal: 25
# Number of rows with all compared columns equal: 77
#
# Column Comparison
# -----------------
#
# Number of columns compared with some values unequal: 5
# Number of columns compared with all values equal: 67
# Total number of values which compare unequal: 100
#
# Columns with Unequal Values or Types
# ------------------------------------
#
#                       Column from_nis dtype from_country dtype  # Unequal  Max Diff  # Null Diff
# 4  programmatic decision mda         object             object         17       0.0           17
# 0              review status         object             object         25       0.0            0
# 1             survey status*         object             object         24       0.0            0
# 2       survey tf result (%)         object             object         17       0.0           17
# 3       survey tt result (%)         object             object         17       0.0           17
#
# Sample Rows with Unequal Values
# -------------------------------
#
#    eu-tr evaluation unit - trachoma*    event uid review status (from_nis) review status (from_country)
# 0         ET-TR-EU-493246-Gulomekeda  YwhuyliGEEX                 Reviewed                 Not reviewed
# 1               ET-TR-EU-870616-Rama  HaNn3kWwIjo                 Reviewed                 Not reviewed
# 2          ET-TR-EU-148517-Daba guna  ukIu0Tuz38r                 Reviewed                 Not reviewed
# 3       ET-TR-EU-099410-Laelaymachew  EnHYoEGyywi                 Reviewed                 Not reviewed
# 4        ET-TR-EU-854095-Edaga Hamus  SGMGF7b8wqM                 Reviewed                 Not reviewed
# 5        ET-TR-EU-418139-Tsaeda Emba  SznNe4cuDiB                 Reviewed                 Not reviewed
# 6      ET-TR-EU-977569-Tahtay Koraro  jLTdT5Nf1c1                 Reviewed                 Not reviewed
# 7             ET-TR-EU-522325-Naeder  NRbmqPt9Gv1                 Reviewed                 Not reviewed
# 8            ET-TR-EU-210905-Seyemti  rQ5miO9R1qO                 Reviewed                 Not reviewed
# 9            ET-TR-EU-605070-Tsimbla  wAjiN87rYId                 Reviewed                 Not reviewed
# 10              ET-TR-EU-892172-Adet  YD9i0YnFVYM                 Reviewed                 Not reviewed
# 11     ET-TR-EU-999950-Tahtay Adyabo  yntxGg0ZLC3                 Reviewed                 Not reviewed
# 12     ET-TR-EU-351504-Laelay Adyabo  GEoKztNkbDC                 Reviewed                 Not reviewed
# 13             ET-TR-EU-182142-Bizet  FThQpeGwEHG                 Reviewed                 Not reviewed
# 14             ET-TR-EU-045454-Chila  OlaEGUBGTZ8                 Reviewed                 Not reviewed
# 15  ET-TR-EU-238968-Abergele Yechila  ZjRvWe9Zyux                 Reviewed                 Not reviewed
# 16     ET-TR-EU-924594-Maekel Adyabo  v487CUDRJiv                 Reviewed                 Not reviewed
# 17          ET-TR-EU-914506-Freweyni  gEcU7YfX3Ed                 Reviewed                 Not reviewed
# 18      ET-TR-EU-706350-Tahtaymachew  gg5TY9aXqyf                 Reviewed                 Not reviewed
# 19        ET-TR-EU-313920-Tankamlash  IBKkdMhlXHc                 Reviewed                 Not reviewed
# 20            ET-TR-EU-859449-Asgede  VRb9pTQJUs9                 Reviewed                 Not reviewed
# 21       ET-TR-EU-851364-Subhasaesie  kOMIuEgLBnn                 Reviewed                 Not reviewed
# 22             ET-TR-EU-544962-Ahsea  oZjtz0KgVgl                 Reviewed                 Not reviewed
# 23     ET-TR-EU-543137-Ganta Afeshum  CdfAZzalB7F                 Reviewed                 Not reviewed
# 24         ET-TR-EU-620206-Adi Daero  CeogTBgoaHb                 Reviewed                 Not reviewed
#
#    eu-tr evaluation unit - trachoma*    event uid               survey status* (from_nis)   survey status* (from_country)
# 0       ET-TR-EU-706350-Tahtaymachew  gg5TY9aXqyf                                 Planned  Completed; final data reported
# 1        ET-TR-EU-851364-Subhasaesie  kOMIuEgLBnn  Completed; final data not yet reported  Completed; final data reported
# 2   ET-TR-EU-238968-Abergele Yechila  ZjRvWe9Zyux                                 Planned         Postponed to another FY
# 3       ET-TR-EU-099410-Laelaymachew  EnHYoEGyywi                                 Planned  Completed; final data reported
# 4      ET-TR-EU-977569-Tahtay Koraro  jLTdT5Nf1c1                                 Planned         Postponed to another FY
# 5            ET-TR-EU-210905-Seyemti  rQ5miO9R1qO                                 Planned  Completed; final data reported
# 6              ET-TR-EU-045454-Chila  OlaEGUBGTZ8  Completed; final data not yet reported  Completed; final data reported
# 7      ET-TR-EU-924594-Maekel Adyabo  v487CUDRJiv                                 Planned  Completed; final data reported
# 8      ET-TR-EU-999950-Tahtay Adyabo  yntxGg0ZLC3                                 Planned         Postponed to another FY
# 9              ET-TR-EU-544962-Ahsea  oZjtz0KgVgl  Completed; final data not yet reported  Completed; final data reported
# 10     ET-TR-EU-543137-Ganta Afeshum  CdfAZzalB7F                                 Planned         Postponed to another FY
# 11             ET-TR-EU-182142-Bizet  FThQpeGwEHG                                 Planned         Postponed to another FY
# 12       ET-TR-EU-854095-Edaga Hamus  SGMGF7b8wqM  Completed; final data not yet reported  Completed; final data reported
# 13        ET-TR-EU-313920-Tankamlash  IBKkdMhlXHc                                 Planned         Postponed to another FY
# 14         ET-TR-EU-148517-Daba guna  ukIu0Tuz38r  Completed; final data not yet reported  Completed; final data reported
# 15           ET-TR-EU-605070-Tsimbla  wAjiN87rYId                                 Planned  Completed; final data reported
# 16          ET-TR-EU-914506-Freweyni  gEcU7YfX3Ed  Completed; final data not yet reported  Completed; final data reported
# 17        ET-TR-EU-493246-Gulomekeda  YwhuyliGEEX                                 Planned         Postponed to another FY
# 18       ET-TR-EU-418139-Tsaeda Emba  SznNe4cuDiB  Completed; final data not yet reported  Completed; final data reported
# 19            ET-TR-EU-522325-Naeder  NRbmqPt9Gv1                                 Planned  Completed; final data reported
# 20         ET-TR-EU-620206-Adi Daero  CeogTBgoaHb                                 Planned  Completed; final data reported
# 21              ET-TR-EU-892172-Adet  YD9i0YnFVYM                                 Planned  Completed; final data reported
# 22            ET-TR-EU-859449-Asgede  VRb9pTQJUs9                                 Planned  Completed; final data reported
# 23              ET-TR-EU-870616-Rama  HaNn3kWwIjo  Completed; final data not yet reported  Completed; final data reported
#
#    eu-tr evaluation unit - trachoma*    event uid survey tf result (%) (from_nis) survey tf result (%) (from_country)
# 0      ET-TR-EU-924594-Maekel Adyabo  v487CUDRJiv                             NaN                                6.78
# 1        ET-TR-EU-851364-Subhasaesie  kOMIuEgLBnn                             NaN                               12.88
# 2               ET-TR-EU-870616-Rama  HaNn3kWwIjo                             NaN                               11.23
# 3           ET-TR-EU-914506-Freweyni  gEcU7YfX3Ed                             NaN                               18.81
# 4       ET-TR-EU-706350-Tahtaymachew  gg5TY9aXqyf                             NaN                                7.11
# 5       ET-TR-EU-099410-Laelaymachew  EnHYoEGyywi                             NaN                                8.71
# 6             ET-TR-EU-859449-Asgede  VRb9pTQJUs9                             NaN                                7.44
# 7            ET-TR-EU-210905-Seyemti  rQ5miO9R1qO                             NaN                                9.26
# 8            ET-TR-EU-605070-Tsimbla  wAjiN87rYId                             NaN                                8.79
# 9               ET-TR-EU-892172-Adet  YD9i0YnFVYM                             NaN                               11.47
# 10             ET-TR-EU-544962-Ahsea  oZjtz0KgVgl                             NaN                               13.28
# 11         ET-TR-EU-620206-Adi Daero  CeogTBgoaHb                             NaN                                7.27
# 12             ET-TR-EU-045454-Chila  OlaEGUBGTZ8                             NaN                                13.4
# 13         ET-TR-EU-148517-Daba guna  ukIu0Tuz38r                             NaN                                   9
# 14       ET-TR-EU-418139-Tsaeda Emba  SznNe4cuDiB                             NaN                               13.69
# 15            ET-TR-EU-522325-Naeder  NRbmqPt9Gv1                             NaN                                  16
# 16       ET-TR-EU-854095-Edaga Hamus  SGMGF7b8wqM                             NaN                                11.1
#
#    eu-tr evaluation unit - trachoma*    event uid survey tt result (%) (from_nis) survey tt result (%) (from_country)
# 0            ET-TR-EU-605070-Tsimbla  wAjiN87rYId                             NaN                               1.109
# 1            ET-TR-EU-210905-Seyemti  rQ5miO9R1qO                             NaN                               0.423
# 2               ET-TR-EU-870616-Rama  HaNn3kWwIjo                             NaN                               0.345
# 3               ET-TR-EU-892172-Adet  YD9i0YnFVYM                             NaN                                0.88
# 4              ET-TR-EU-045454-Chila  OlaEGUBGTZ8                             NaN                               0.973
# 5       ET-TR-EU-099410-Laelaymachew  EnHYoEGyywi                             NaN                               0.735
# 6      ET-TR-EU-924594-Maekel Adyabo  v487CUDRJiv                             NaN                               0.685
# 7          ET-TR-EU-620206-Adi Daero  CeogTBgoaHb                             NaN                               1.079
# 8             ET-TR-EU-522325-Naeder  NRbmqPt9Gv1                             NaN                               1.057
# 9           ET-TR-EU-914506-Freweyni  gEcU7YfX3Ed                             NaN                               0.582
# 10       ET-TR-EU-854095-Edaga Hamus  SGMGF7b8wqM                             NaN                               0.243
# 11             ET-TR-EU-544962-Ahsea  oZjtz0KgVgl                             NaN                               0.942
# 12            ET-TR-EU-859449-Asgede  VRb9pTQJUs9                             NaN                               0.322
# 13       ET-TR-EU-418139-Tsaeda Emba  SznNe4cuDiB                             NaN                               0.604
# 14         ET-TR-EU-148517-Daba guna  ukIu0Tuz38r                             NaN                               0.477
# 15      ET-TR-EU-706350-Tahtaymachew  gg5TY9aXqyf                             NaN                               1.163
# 16       ET-TR-EU-851364-Subhasaesie  kOMIuEgLBnn                             NaN                               0.423
#
#    eu-tr evaluation unit - trachoma*    event uid programmatic decision mda (from_nis) programmatic decision mda (from_country)
# 0       ET-TR-EU-706350-Tahtaymachew  gg5TY9aXqyf                                  NaN                  Continue or restart MDA
# 1           ET-TR-EU-914506-Freweyni  gEcU7YfX3Ed                                  NaN                  Continue or restart MDA
# 2             ET-TR-EU-859449-Asgede  VRb9pTQJUs9                                  NaN                  Continue or restart MDA
# 3          ET-TR-EU-620206-Adi Daero  CeogTBgoaHb                                  NaN                  Continue or restart MDA
# 4       ET-TR-EU-099410-Laelaymachew  EnHYoEGyywi                                  NaN                  Continue or restart MDA
# 5              ET-TR-EU-045454-Chila  OlaEGUBGTZ8                                  NaN                  Continue or restart MDA
# 6        ET-TR-EU-854095-Edaga Hamus  SGMGF7b8wqM                                  NaN                  Continue or restart MDA
# 7               ET-TR-EU-870616-Rama  HaNn3kWwIjo                                  NaN                  Continue or restart MDA
# 8            ET-TR-EU-210905-Seyemti  rQ5miO9R1qO                                  NaN                  Continue or restart MDA
# 9          ET-TR-EU-148517-Daba guna  ukIu0Tuz38r                                  NaN                  Continue or restart MDA
# 10              ET-TR-EU-892172-Adet  YD9i0YnFVYM                                  NaN                  Continue or restart MDA
# 11       ET-TR-EU-851364-Subhasaesie  kOMIuEgLBnn                                  NaN                  Continue or restart MDA
# 12       ET-TR-EU-418139-Tsaeda Emba  SznNe4cuDiB                                  NaN                  Continue or restart MDA
# 13            ET-TR-EU-522325-Naeder  NRbmqPt9Gv1                                  NaN                  Continue or restart MDA
# 14             ET-TR-EU-544962-Ahsea  oZjtz0KgVgl                                  NaN                  Continue or restart MDA
# 15     ET-TR-EU-924594-Maekel Adyabo  v487CUDRJiv                                  NaN                  Continue or restart MDA
# 16           ET-TR-EU-605070-Tsimbla  wAjiN87rYId                                  NaN                  Continue or restart MDA
#
#
# DataComPy Comparison
# --------------------
#
# DataFrame Summary
# -----------------
#
#       DataFrame  Columns  Rows
# 0      from_nis       73   102
# 1  from_country       73   102
#
# Column Summary
# --------------
#
# Number of columns in common: 72
# Number of columns in from_nis but not in from_country: 1
# Number of columns in from_country but not in from_nis: 1
#
# Row Summary
# -----------
#
# Matched on: eu-tr evaluation unit - trachoma*, fy
# Any duplicates on match values: No
# Absolute Tolerance: 0
# Relative Tolerance: 0
# Number of rows in common: 102
# Number of rows in from_nis but not in from_country: 0
# Number of rows in from_country but not in from_nis: 0
#
# Number of rows with some compared columns unequal: 25
# Number of rows with all compared columns equal: 77
#
# Column Comparison
# -----------------
#
# Number of columns compared with some values unequal: 5
# Number of columns compared with all values equal: 67
# Total number of values which compare unequal: 100
#
# Columns with Unequal Values or Types
# ------------------------------------
#
#                       Column from_nis dtype from_country dtype  # Unequal  Max Diff  # Null Diff
# 4  programmatic decision mda         object             object         17       0.0           17
# 0              review status         object             object         25       0.0            0
# 1             survey status*         object             object         24       0.0            0
# 2       survey tf result (%)         object             object         17       0.0           17
# 3       survey tt result (%)         object             object         17       0.0           17
#
# Sample Rows with Unequal Values
# -------------------------------
#
#    eu-tr evaluation unit - trachoma*    fy review status (from_nis) review status (from_country)
# 0        ET-TR-EU-854095-Edaga Hamus  2024                 Reviewed                 Not reviewed
# 1               ET-TR-EU-892172-Adet  2024                 Reviewed                 Not reviewed
# 2      ET-TR-EU-977569-Tahtay Koraro  2024                 Reviewed                 Not reviewed
# 3      ET-TR-EU-999950-Tahtay Adyabo  2024                 Reviewed                 Not reviewed
# 4      ET-TR-EU-543137-Ganta Afeshum  2024                 Reviewed                 Not reviewed
# 5             ET-TR-EU-522325-Naeder  2024                 Reviewed                 Not reviewed
# 6              ET-TR-EU-544962-Ahsea  2024                 Reviewed                 Not reviewed
# 7         ET-TR-EU-493246-Gulomekeda  2024                 Reviewed                 Not reviewed
# 8       ET-TR-EU-706350-Tahtaymachew  2024                 Reviewed                 Not reviewed
# 9             ET-TR-EU-859449-Asgede  2024                 Reviewed                 Not reviewed
# 10       ET-TR-EU-851364-Subhasaesie  2024                 Reviewed                 Not reviewed
# 11  ET-TR-EU-238968-Abergele Yechila  2024                 Reviewed                 Not reviewed
# 12         ET-TR-EU-620206-Adi Daero  2024                 Reviewed                 Not reviewed
# 13           ET-TR-EU-210905-Seyemti  2024                 Reviewed                 Not reviewed
# 14          ET-TR-EU-914506-Freweyni  2024                 Reviewed                 Not reviewed
# 15      ET-TR-EU-099410-Laelaymachew  2024                 Reviewed                 Not reviewed
# 16       ET-TR-EU-418139-Tsaeda Emba  2024                 Reviewed                 Not reviewed
# 17             ET-TR-EU-045454-Chila  2024                 Reviewed                 Not reviewed
# 18     ET-TR-EU-351504-Laelay Adyabo  2024                 Reviewed                 Not reviewed
# 19        ET-TR-EU-313920-Tankamlash  2024                 Reviewed                 Not reviewed
# 20             ET-TR-EU-182142-Bizet  2024                 Reviewed                 Not reviewed
# 21           ET-TR-EU-605070-Tsimbla  2024                 Reviewed                 Not reviewed
# 22         ET-TR-EU-148517-Daba guna  2024                 Reviewed                 Not reviewed
# 23              ET-TR-EU-870616-Rama  2024                 Reviewed                 Not reviewed
# 24     ET-TR-EU-924594-Maekel Adyabo  2024                 Reviewed                 Not reviewed
#
#    eu-tr evaluation unit - trachoma*    fy               survey status* (from_nis)   survey status* (from_country)
# 0              ET-TR-EU-045454-Chila  2024  Completed; final data not yet reported  Completed; final data reported
# 1      ET-TR-EU-543137-Ganta Afeshum  2024                                 Planned         Postponed to another FY
# 2          ET-TR-EU-148517-Daba guna  2024  Completed; final data not yet reported  Completed; final data reported
# 3             ET-TR-EU-522325-Naeder  2024                                 Planned  Completed; final data reported
# 4        ET-TR-EU-851364-Subhasaesie  2024  Completed; final data not yet reported  Completed; final data reported
# 5               ET-TR-EU-870616-Rama  2024  Completed; final data not yet reported  Completed; final data reported
# 6           ET-TR-EU-914506-Freweyni  2024  Completed; final data not yet reported  Completed; final data reported
# 7       ET-TR-EU-099410-Laelaymachew  2024                                 Planned  Completed; final data reported
# 8             ET-TR-EU-859449-Asgede  2024                                 Planned  Completed; final data reported
# 9       ET-TR-EU-706350-Tahtaymachew  2024                                 Planned  Completed; final data reported
# 10       ET-TR-EU-854095-Edaga Hamus  2024  Completed; final data not yet reported  Completed; final data reported
# 11             ET-TR-EU-182142-Bizet  2024                                 Planned         Postponed to another FY
# 12     ET-TR-EU-977569-Tahtay Koraro  2024                                 Planned         Postponed to another FY
# 13       ET-TR-EU-418139-Tsaeda Emba  2024  Completed; final data not yet reported  Completed; final data reported
# 14     ET-TR-EU-924594-Maekel Adyabo  2024                                 Planned  Completed; final data reported
# 15              ET-TR-EU-892172-Adet  2024                                 Planned  Completed; final data reported
# 16           ET-TR-EU-605070-Tsimbla  2024                                 Planned  Completed; final data reported
# 17     ET-TR-EU-999950-Tahtay Adyabo  2024                                 Planned         Postponed to another FY
# 18           ET-TR-EU-210905-Seyemti  2024                                 Planned  Completed; final data reported
# 19        ET-TR-EU-493246-Gulomekeda  2024                                 Planned         Postponed to another FY
# 20  ET-TR-EU-238968-Abergele Yechila  2024                                 Planned         Postponed to another FY
# 21         ET-TR-EU-620206-Adi Daero  2024                                 Planned  Completed; final data reported
# 22        ET-TR-EU-313920-Tankamlash  2024                                 Planned         Postponed to another FY
# 23             ET-TR-EU-544962-Ahsea  2024  Completed; final data not yet reported  Completed; final data reported
#
#    eu-tr evaluation unit - trachoma*    fy survey tf result (%) (from_nis) survey tf result (%) (from_country)
# 0               ET-TR-EU-892172-Adet  2024                             NaN                               11.47
# 1       ET-TR-EU-099410-Laelaymachew  2024                             NaN                                8.71
# 2       ET-TR-EU-706350-Tahtaymachew  2024                             NaN                                7.11
# 3              ET-TR-EU-045454-Chila  2024                             NaN                                13.4
# 4          ET-TR-EU-620206-Adi Daero  2024                             NaN                                7.27
# 5              ET-TR-EU-544962-Ahsea  2024                             NaN                               13.28
# 6        ET-TR-EU-418139-Tsaeda Emba  2024                             NaN                               13.69
# 7        ET-TR-EU-851364-Subhasaesie  2024                             NaN                               12.88
# 8      ET-TR-EU-924594-Maekel Adyabo  2024                             NaN                                6.78
# 9        ET-TR-EU-854095-Edaga Hamus  2024                             NaN                                11.1
# 10            ET-TR-EU-859449-Asgede  2024                             NaN                                7.44
# 11          ET-TR-EU-914506-Freweyni  2024                             NaN                               18.81
# 12         ET-TR-EU-148517-Daba guna  2024                             NaN                                   9
# 13           ET-TR-EU-605070-Tsimbla  2024                             NaN                                8.79
# 14           ET-TR-EU-210905-Seyemti  2024                             NaN                                9.26
# 15              ET-TR-EU-870616-Rama  2024                             NaN                               11.23
# 16            ET-TR-EU-522325-Naeder  2024                             NaN                                  16
#
#    eu-tr evaluation unit - trachoma*    fy survey tt result (%) (from_nis) survey tt result (%) (from_country)
# 0          ET-TR-EU-148517-Daba guna  2024                             NaN                               0.477
# 1            ET-TR-EU-605070-Tsimbla  2024                             NaN                               1.109
# 2              ET-TR-EU-045454-Chila  2024                             NaN                               0.973
# 3          ET-TR-EU-620206-Adi Daero  2024                             NaN                               1.079
# 4             ET-TR-EU-859449-Asgede  2024                             NaN                               0.322
# 5            ET-TR-EU-210905-Seyemti  2024                             NaN                               0.423
# 6        ET-TR-EU-418139-Tsaeda Emba  2024                             NaN                               0.604
# 7      ET-TR-EU-924594-Maekel Adyabo  2024                             NaN                               0.685
# 8       ET-TR-EU-706350-Tahtaymachew  2024                             NaN                               1.163
# 9        ET-TR-EU-851364-Subhasaesie  2024                             NaN                               0.423
# 10          ET-TR-EU-914506-Freweyni  2024                             NaN                               0.582
# 11      ET-TR-EU-099410-Laelaymachew  2024                             NaN                               0.735
# 12              ET-TR-EU-870616-Rama  2024                             NaN                               0.345
# 13            ET-TR-EU-522325-Naeder  2024                             NaN                               1.057
# 14              ET-TR-EU-892172-Adet  2024                             NaN                                0.88
# 15       ET-TR-EU-854095-Edaga Hamus  2024                             NaN                               0.243
# 16             ET-TR-EU-544962-Ahsea  2024                             NaN                               0.942
#
#    eu-tr evaluation unit - trachoma*    fy programmatic decision mda (from_nis) programmatic decision mda (from_country)
# 0              ET-TR-EU-544962-Ahsea  2024                                  NaN                  Continue or restart MDA
# 1        ET-TR-EU-851364-Subhasaesie  2024                                  NaN                  Continue or restart MDA
# 2            ET-TR-EU-210905-Seyemti  2024                                  NaN                  Continue or restart MDA
# 3             ET-TR-EU-859449-Asgede  2024                                  NaN                  Continue or restart MDA
# 4             ET-TR-EU-522325-Naeder  2024                                  NaN                  Continue or restart MDA
# 5            ET-TR-EU-605070-Tsimbla  2024                                  NaN                  Continue or restart MDA
# 6               ET-TR-EU-892172-Adet  2024                                  NaN                  Continue or restart MDA
# 7          ET-TR-EU-620206-Adi Daero  2024                                  NaN                  Continue or restart MDA
# 8       ET-TR-EU-099410-Laelaymachew  2024                                  NaN                  Continue or restart MDA
# 9          ET-TR-EU-148517-Daba guna  2024                                  NaN                  Continue or restart MDA
# 10       ET-TR-EU-854095-Edaga Hamus  2024                                  NaN                  Continue or restart MDA
# 11       ET-TR-EU-418139-Tsaeda Emba  2024                                  NaN                  Continue or restart MDA
# 12          ET-TR-EU-914506-Freweyni  2024                                  NaN                  Continue or restart MDA
# 13     ET-TR-EU-924594-Maekel Adyabo  2024                                  NaN                  Continue or restart MDA
# 14      ET-TR-EU-706350-Tahtaymachew  2024                                  NaN                  Continue or restart MDA
# 15              ET-TR-EU-870616-Rama  2024                                  NaN                  Continue or restart MDA
# 16             ET-TR-EU-045454-Chila  2024                                  NaN                  Continue or restart MDA

# %% [markdown]
# ### Output Summary File

# %%
print(compare_EU_uid.all_mismatch())
with open(summary_output_EU_uid, 'w', encoding='utf-8') as report_file:
    report_file.write(compare_EU_uid.report(sample_count=1000000))

print(compare_EU_FY.all_mismatch())
with open(summary_output_EU_FY, 'w', encoding='utf-8') as report_file:
    report_file.write(compare_EU_FY.report(sample_count=1000000))
# Out:
#     eu-tr evaluation unit - trachoma*    event uid  \
# 3               ET-TR-EU-045454-Chila  OlaEGUBGTZ8
# 10       ET-TR-EU-099410-Laelaymachew  EnHYoEGyywi
# 14          ET-TR-EU-148517-Daba guna  ukIu0Tuz38r
# 16              ET-TR-EU-182142-Bizet  FThQpeGwEHG
# 20            ET-TR-EU-210905-Seyemti  rQ5miO9R1qO
# 23   ET-TR-EU-238968-Abergele Yechila  ZjRvWe9Zyux
# 31         ET-TR-EU-313920-Tankamlash  IBKkdMhlXHc
# 36      ET-TR-EU-351504-Laelay Adyabo  GEoKztNkbDC
# 41        ET-TR-EU-418139-Tsaeda Emba  SznNe4cuDiB
# 48         ET-TR-EU-493246-Gulomekeda  YwhuyliGEEX
# 51             ET-TR-EU-522325-Naeder  NRbmqPt9Gv1
# 54      ET-TR-EU-543137-Ganta Afeshum  CdfAZzalB7F
# 55              ET-TR-EU-544962-Ahsea  oZjtz0KgVgl
# 64            ET-TR-EU-605070-Tsimbla  wAjiN87rYId
# 66          ET-TR-EU-620206-Adi Daero  CeogTBgoaHb
# 69       ET-TR-EU-706350-Tahtaymachew  gg5TY9aXqyf
# 85        ET-TR-EU-851364-Subhasaesie  kOMIuEgLBnn
# 86        ET-TR-EU-854095-Edaga Hamus  SGMGF7b8wqM
# 88             ET-TR-EU-859449-Asgede  VRb9pTQJUs9
# 90               ET-TR-EU-870616-Rama  HaNn3kWwIjo
# 93               ET-TR-EU-892172-Adet  YD9i0YnFVYM
# 95           ET-TR-EU-914506-Freweyni  gEcU7YfX3Ed
# 96      ET-TR-EU-924594-Maekel Adyabo  v487CUDRJiv
# 99      ET-TR-EU-977569-Tahtay Koraro  jLTdT5Nf1c1
# 101     ET-TR-EU-999950-Tahtay Adyabo  yntxGg0ZLC3
#
#     organisation unit*_from_nis organisation unit*_from_country  \
# 3                      Ethiopia                        Ethiopia
# 10                     Ethiopia                        Ethiopia
# 14                     Ethiopia                        Ethiopia
# 16                     Ethiopia                        Ethiopia
# 20                     Ethiopia                        Ethiopia
# 23                     Ethiopia                        Ethiopia
# 31                     Ethiopia                        Ethiopia
# 36                     Ethiopia                        Ethiopia
# 41                     Ethiopia                        Ethiopia
# 48                     Ethiopia                        Ethiopia
# 51                     Ethiopia                        Ethiopia
# 54                     Ethiopia                        Ethiopia
# 55                     Ethiopia                        Ethiopia
# 64                     Ethiopia                        Ethiopia
# 66                     Ethiopia                        Ethiopia
# 69                     Ethiopia                        Ethiopia
# 85                     Ethiopia                        Ethiopia
# 86                     Ethiopia                        Ethiopia
# 88                     Ethiopia                        Ethiopia
# 90                     Ethiopia                        Ethiopia
# 93                     Ethiopia                        Ethiopia
# 95                     Ethiopia                        Ethiopia
# 96                     Ethiopia                        Ethiopia
# 99                     Ethiopia                        Ethiopia
# 101                    Ethiopia                        Ethiopia
#
#     latitude_from_nis latitude_from_country longitude_from_nis  \
# 3                 NaN                   NaN                NaN
# 10                NaN                   NaN                NaN
# 14                NaN                   NaN                NaN
# 16                NaN                   NaN                NaN
# 20                NaN                   NaN                NaN
# 23                NaN                   NaN                NaN
# 31                NaN                   NaN                NaN
# 36                NaN                   NaN                NaN
# 41                NaN                   NaN                NaN
# 48                NaN                   NaN                NaN
# 51                NaN                   NaN                NaN
# 54                NaN                   NaN                NaN
# 55                NaN                   NaN                NaN
# 64                NaN                   NaN                NaN
# 66                NaN                   NaN                NaN
# 69                NaN                   NaN                NaN
# 85                NaN                   NaN                NaN
# 86                NaN                   NaN                NaN
# 88                NaN                   NaN                NaN
# 90                NaN                   NaN                NaN
# 93                NaN                   NaN                NaN
# 95                NaN                   NaN                NaN
# 96                NaN                   NaN                NaN
# 99                NaN                   NaN                NaN
# 101               NaN                   NaN                NaN
#
#     longitude_from_country status_from_nis status_from_country  ...  \
# 3                      NaN       COMPLETED           COMPLETED  ...
# 10                     NaN       COMPLETED           COMPLETED  ...
# 14                     NaN       COMPLETED           COMPLETED  ...
# 16                     NaN       COMPLETED           COMPLETED  ...
# 20                     NaN       COMPLETED           COMPLETED  ...
# 23                     NaN       COMPLETED           COMPLETED  ...
# 31                     NaN       COMPLETED           COMPLETED  ...
# 36                     NaN       COMPLETED           COMPLETED  ...
# 41                     NaN       COMPLETED           COMPLETED  ...
# 48                     NaN       COMPLETED           COMPLETED  ...
# 51                     NaN       COMPLETED           COMPLETED  ...
# 54                     NaN       COMPLETED           COMPLETED  ...
# 55                     NaN       COMPLETED           COMPLETED  ...
# 64                     NaN       COMPLETED           COMPLETED  ...
# 66                     NaN       COMPLETED           COMPLETED  ...
# 69                     NaN       COMPLETED           COMPLETED  ...
# 85                     NaN       COMPLETED           COMPLETED  ...
# 86                     NaN       COMPLETED           COMPLETED  ...
# 88                     NaN       COMPLETED           COMPLETED  ...
# 90                     NaN       COMPLETED           COMPLETED  ...
# 93                     NaN       COMPLETED           COMPLETED  ...
# 95                     NaN       COMPLETED           COMPLETED  ...
# 96                     NaN       COMPLETED           COMPLETED  ...
# 99                     NaN       COMPLETED           COMPLETED  ...
# 101                    NaN       COMPLETED           COMPLETED  ...
#
#     is 'original planned date' missing?_from_nis  \
# 3                                          false
# 10                                         false
# 14                                         false
# 16                                         false
# 20                                         false
# 23                                         false
# 31                                         false
# 36                                         false
# 41                                         false
# 48                                         false
# 51                                         false
# 54                                         false
# 55                                         false
# 64                                         false
# 66                                         false
# 69                                         false
# 85                                         false
# 86                                         false
# 88                                         false
# 90                                         false
# 93                                         false
# 95                                         false
# 96                                         false
# 99                                         false
# 101                                        false
#
#     is 'original planned date' missing?_from_country  \
# 3                                              false
# 10                                             false
# 14                                             false
# 16                                             false
# 20                                             false
# 23                                             false
# 31                                             false
# 36                                             false
# 41                                             false
# 48                                             false
# 51                                             false
# 54                                             false
# 55                                             false
# 64                                             false
# 66                                             false
# 69                                             false
# 85                                             false
# 86                                             false
# 88                                             false
# 90                                             false
# 93                                             false
# 95                                             false
# 96                                             false
# 99                                             false
# 101                                            false
#
#     is 'funding source' missing?_from_nis  \
# 3                                   false
# 10                                  false
# 14                                  false
# 16                                  false
# 20                                  false
# 23                                  false
# 31                                  false
# 36                                  false
# 41                                  false
# 48                                  false
# 51                                  false
# 54                                  false
# 55                                  false
# 64                                  false
# 66                                  false
# 69                                  false
# 85                                  false
# 86                                  false
# 88                                  false
# 90                                  false
# 93                                  false
# 95                                  false
# 96                                  false
# 99                                  false
# 101                                 false
#
#     is 'funding source' missing?_from_country  \
# 3                                       false
# 10                                      false
# 14                                      false
# 16                                      false
# 20                                      false
# 23                                      false
# 31                                      false
# 36                                      false
# 41                                      false
# 48                                      false
# 51                                      false
# 54                                      false
# 55                                      false
# 64                                      false
# 66                                      false
# 69                                      false
# 85                                      false
# 86                                      false
# 88                                      false
# 90                                      false
# 93                                      false
# 95                                      false
# 96                                      false
# 99                                      false
# 101                                     false
#
#     is 'eu population' missing?_from_nis  \
# 3                                  false
# 10                                 false
# 14                                 false
# 16                                 false
# 20                                 false
# 23                                 false
# 31                                 false
# 36                                 false
# 41                                 false
# 48                                 false
# 51                                 false
# 54                                 false
# 55                                 false
# 64                                 false
# 66                                 false
# 69                                 false
# 85                                 false
# 86                                 false
# 88                                 false
# 90                                 false
# 93                                 false
# 95                                 false
# 96                                 false
# 99                                 false
# 101                                false
#
#     is 'eu population' missing?_from_country  \
# 3                                      false
# 10                                     false
# 14                                     false
# 16                                     false
# 20                                     false
# 23                                     false
# 31                                     false
# 36                                     false
# 41                                     false
# 48                                     false
# 51                                     false
# 54                                     false
# 55                                     false
# 64                                     false
# 66                                     false
# 69                                     false
# 85                                     false
# 86                                     false
# 88                                     false
# 90                                     false
# 93                                     false
# 95                                     false
# 96                                     false
# 99                                     false
# 101                                    false
#
#     is 'survey tf result (%)' missing?_from_nis  \
# 3                                           NaN
# 10                                          NaN
# 14                                          NaN
# 16                                          NaN
# 20                                          NaN
# 23                                          NaN
# 31                                          NaN
# 36                                          NaN
# 41                                          NaN
# 48                                          NaN
# 51                                          NaN
# 54                                          NaN
# 55                                          NaN
# 64                                          NaN
# 66                                          NaN
# 69                                          NaN
# 85                                          NaN
# 86                                          NaN
# 88                                          NaN
# 90                                          NaN
# 93                                          NaN
# 95                                          NaN
# 96                                          NaN
# 99                                          NaN
# 101                                         NaN
#
#     is 'survey tf result (%)' missing?_from_country  \
# 3                                               NaN
# 10                                              NaN
# 14                                              NaN
# 16                                              NaN
# 20                                              NaN
# 23                                              NaN
# 31                                              NaN
# 36                                              NaN
# 41                                              NaN
# 48                                              NaN
# 51                                              NaN
# 54                                              NaN
# 55                                              NaN
# 64                                              NaN
# 66                                              NaN
# 69                                              NaN
# 85                                              NaN
# 86                                              NaN
# 88                                              NaN
# 90                                              NaN
# 93                                              NaN
# 95                                              NaN
# 96                                              NaN
# 99                                              NaN
# 101                                             NaN
#
#     is 'survey tt result (%)' missing?_from_nis  \
# 3                                           NaN
# 10                                          NaN
# 14                                          NaN
# 16                                          NaN
# 20                                          NaN
# 23                                          NaN
# 31                                          NaN
# 36                                          NaN
# 41                                          NaN
# 48                                          NaN
# 51                                          NaN
# 54                                          NaN
# 55                                          NaN
# 64                                          NaN
# 66                                          NaN
# 69                                          NaN
# 85                                          NaN
# 86                                          NaN
# 88                                          NaN
# 90                                          NaN
# 93                                          NaN
# 95                                          NaN
# 96                                          NaN
# 99                                          NaN
# 101                                         NaN
#
#     is 'survey tt result (%)' missing?_from_country
# 3                                               NaN
# 10                                              NaN
# 14                                              NaN
# 16                                              NaN
# 20                                              NaN
# 23                                              NaN
# 31                                              NaN
# 36                                              NaN
# 41                                              NaN
# 48                                              NaN
# 51                                              NaN
# 54                                              NaN
# 55                                              NaN
# 64                                              NaN
# 66                                              NaN
# 69                                              NaN
# 85                                              NaN
# 86                                              NaN
# 88                                              NaN
# 90                                              NaN
# 93                                              NaN
# 95                                              NaN
# 96                                              NaN
# 99                                              NaN
# 101                                             NaN
#
# [25 rows x 142 columns]
#     eu-tr evaluation unit - trachoma*    fy event uid_from_nis  \
# 3               ET-TR-EU-045454-Chila  2024        OlaEGUBGTZ8
# 10       ET-TR-EU-099410-Laelaymachew  2024        EnHYoEGyywi
# 14          ET-TR-EU-148517-Daba guna  2024        ukIu0Tuz38r
# 16              ET-TR-EU-182142-Bizet  2024        FThQpeGwEHG
# 20            ET-TR-EU-210905-Seyemti  2024        rQ5miO9R1qO
# 23   ET-TR-EU-238968-Abergele Yechila  2024        ZjRvWe9Zyux
# 31         ET-TR-EU-313920-Tankamlash  2024        IBKkdMhlXHc
# 36      ET-TR-EU-351504-Laelay Adyabo  2024        GEoKztNkbDC
# 41        ET-TR-EU-418139-Tsaeda Emba  2024        SznNe4cuDiB
# 48         ET-TR-EU-493246-Gulomekeda  2024        YwhuyliGEEX
# 51             ET-TR-EU-522325-Naeder  2024        NRbmqPt9Gv1
# 54      ET-TR-EU-543137-Ganta Afeshum  2024        CdfAZzalB7F
# 55              ET-TR-EU-544962-Ahsea  2024        oZjtz0KgVgl
# 64            ET-TR-EU-605070-Tsimbla  2024        wAjiN87rYId
# 66          ET-TR-EU-620206-Adi Daero  2024        CeogTBgoaHb
# 69       ET-TR-EU-706350-Tahtaymachew  2024        gg5TY9aXqyf
# 85        ET-TR-EU-851364-Subhasaesie  2024        kOMIuEgLBnn
# 86        ET-TR-EU-854095-Edaga Hamus  2024        SGMGF7b8wqM
# 88             ET-TR-EU-859449-Asgede  2024        VRb9pTQJUs9
# 90               ET-TR-EU-870616-Rama  2024        HaNn3kWwIjo
# 93               ET-TR-EU-892172-Adet  2024        YD9i0YnFVYM
# 95           ET-TR-EU-914506-Freweyni  2024        gEcU7YfX3Ed
# 96      ET-TR-EU-924594-Maekel Adyabo  2024        v487CUDRJiv
# 99      ET-TR-EU-977569-Tahtay Koraro  2024        jLTdT5Nf1c1
# 101     ET-TR-EU-999950-Tahtay Adyabo  2024        yntxGg0ZLC3
#
#     event uid_from_country organisation unit*_from_nis  \
# 3              OlaEGUBGTZ8                    Ethiopia
# 10             EnHYoEGyywi                    Ethiopia
# 14             ukIu0Tuz38r                    Ethiopia
# 16             FThQpeGwEHG                    Ethiopia
# 20             rQ5miO9R1qO                    Ethiopia
# 23             ZjRvWe9Zyux                    Ethiopia
# 31             IBKkdMhlXHc                    Ethiopia
# 36             GEoKztNkbDC                    Ethiopia
# 41             SznNe4cuDiB                    Ethiopia
# 48             YwhuyliGEEX                    Ethiopia
# 51             NRbmqPt9Gv1                    Ethiopia
# 54             CdfAZzalB7F                    Ethiopia
# 55             oZjtz0KgVgl                    Ethiopia
# 64             wAjiN87rYId                    Ethiopia
# 66             CeogTBgoaHb                    Ethiopia
# 69             gg5TY9aXqyf                    Ethiopia
# 85             kOMIuEgLBnn                    Ethiopia
# 86             SGMGF7b8wqM                    Ethiopia
# 88             VRb9pTQJUs9                    Ethiopia
# 90             HaNn3kWwIjo                    Ethiopia
# 93             YD9i0YnFVYM                    Ethiopia
# 95             gEcU7YfX3Ed                    Ethiopia
# 96             v487CUDRJiv                    Ethiopia
# 99             jLTdT5Nf1c1                    Ethiopia
# 101            yntxGg0ZLC3                    Ethiopia
#
#     organisation unit*_from_country latitude_from_nis latitude_from_country  \
# 3                          Ethiopia               NaN                   NaN
# 10                         Ethiopia               NaN                   NaN
# 14                         Ethiopia               NaN                   NaN
# 16                         Ethiopia               NaN                   NaN
# 20                         Ethiopia               NaN                   NaN
# 23                         Ethiopia               NaN                   NaN
# 31                         Ethiopia               NaN                   NaN
# 36                         Ethiopia               NaN                   NaN
# 41                         Ethiopia               NaN                   NaN
# 48                         Ethiopia               NaN                   NaN
# 51                         Ethiopia               NaN                   NaN
# 54                         Ethiopia               NaN                   NaN
# 55                         Ethiopia               NaN                   NaN
# 64                         Ethiopia               NaN                   NaN
# 66                         Ethiopia               NaN                   NaN
# 69                         Ethiopia               NaN                   NaN
# 85                         Ethiopia               NaN                   NaN
# 86                         Ethiopia               NaN                   NaN
# 88                         Ethiopia               NaN                   NaN
# 90                         Ethiopia               NaN                   NaN
# 93                         Ethiopia               NaN                   NaN
# 95                         Ethiopia               NaN                   NaN
# 96                         Ethiopia               NaN                   NaN
# 99                         Ethiopia               NaN                   NaN
# 101                        Ethiopia               NaN                   NaN
#
#     longitude_from_nis longitude_from_country  ...  \
# 3                  NaN                    NaN  ...
# 10                 NaN                    NaN  ...
# 14                 NaN                    NaN  ...
# 16                 NaN                    NaN  ...
# 20                 NaN                    NaN  ...
# 23                 NaN                    NaN  ...
# 31                 NaN                    NaN  ...
# 36                 NaN                    NaN  ...
# 41                 NaN                    NaN  ...
# 48                 NaN                    NaN  ...
# 51                 NaN                    NaN  ...
# 54                 NaN                    NaN  ...
# 55                 NaN                    NaN  ...
# 64                 NaN                    NaN  ...
# 66                 NaN                    NaN  ...
# 69                 NaN                    NaN  ...
# 85                 NaN                    NaN  ...
# 86                 NaN                    NaN  ...
# 88                 NaN                    NaN  ...
# 90                 NaN                    NaN  ...
# 93                 NaN                    NaN  ...
# 95                 NaN                    NaN  ...
# 96                 NaN                    NaN  ...
# 99                 NaN                    NaN  ...
# 101                NaN                    NaN  ...
#
#     is 'original planned date' missing?_from_nis  \
# 3                                          false
# 10                                         false
# 14                                         false
# 16                                         false
# 20                                         false
# 23                                         false
# 31                                         false
# 36                                         false
# 41                                         false
# 48                                         false
# 51                                         false
# 54                                         false
# 55                                         false
# 64                                         false
# 66                                         false
# 69                                         false
# 85                                         false
# 86                                         false
# 88                                         false
# 90                                         false
# 93                                         false
# 95                                         false
# 96                                         false
# 99                                         false
# 101                                        false
#
#     is 'original planned date' missing?_from_country  \
# 3                                              false
# 10                                             false
# 14                                             false
# 16                                             false
# 20                                             false
# 23                                             false
# 31                                             false
# 36                                             false
# 41                                             false
# 48                                             false
# 51                                             false
# 54                                             false
# 55                                             false
# 64                                             false
# 66                                             false
# 69                                             false
# 85                                             false
# 86                                             false
# 88                                             false
# 90                                             false
# 93                                             false
# 95                                             false
# 96                                             false
# 99                                             false
# 101                                            false
#
#     is 'funding source' missing?_from_nis  \
# 3                                   false
# 10                                  false
# 14                                  false
# 16                                  false
# 20                                  false
# 23                                  false
# 31                                  false
# 36                                  false
# 41                                  false
# 48                                  false
# 51                                  false
# 54                                  false
# 55                                  false
# 64                                  false
# 66                                  false
# 69                                  false
# 85                                  false
# 86                                  false
# 88                                  false
# 90                                  false
# 93                                  false
# 95                                  false
# 96                                  false
# 99                                  false
# 101                                 false
#
#     is 'funding source' missing?_from_country  \
# 3                                       false
# 10                                      false
# 14                                      false
# 16                                      false
# 20                                      false
# 23                                      false
# 31                                      false
# 36                                      false
# 41                                      false
# 48                                      false
# 51                                      false
# 54                                      false
# 55                                      false
# 64                                      false
# 66                                      false
# 69                                      false
# 85                                      false
# 86                                      false
# 88                                      false
# 90                                      false
# 93                                      false
# 95                                      false
# 96                                      false
# 99                                      false
# 101                                     false
#
#     is 'eu population' missing?_from_nis  \
# 3                                  false
# 10                                 false
# 14                                 false
# 16                                 false
# 20                                 false
# 23                                 false
# 31                                 false
# 36                                 false
# 41                                 false
# 48                                 false
# 51                                 false
# 54                                 false
# 55                                 false
# 64                                 false
# 66                                 false
# 69                                 false
# 85                                 false
# 86                                 false
# 88                                 false
# 90                                 false
# 93                                 false
# 95                                 false
# 96                                 false
# 99                                 false
# 101                                false
#
#     is 'eu population' missing?_from_country  \
# 3                                      false
# 10                                     false
# 14                                     false
# 16                                     false
# 20                                     false
# 23                                     false
# 31                                     false
# 36                                     false
# 41                                     false
# 48                                     false
# 51                                     false
# 54                                     false
# 55                                     false
# 64                                     false
# 66                                     false
# 69                                     false
# 85                                     false
# 86                                     false
# 88                                     false
# 90                                     false
# 93                                     false
# 95                                     false
# 96                                     false
# 99                                     false
# 101                                    false
#
#     is 'survey tf result (%)' missing?_from_nis  \
# 3                                           NaN
# 10                                          NaN
# 14                                          NaN
# 16                                          NaN
# 20                                          NaN
# 23                                          NaN
# 31                                          NaN
# 36                                          NaN
# 41                                          NaN
# 48                                          NaN
# 51                                          NaN
# 54                                          NaN
# 55                                          NaN
# 64                                          NaN
# 66                                          NaN
# 69                                          NaN
# 85                                          NaN
# 86                                          NaN
# 88                                          NaN
# 90                                          NaN
# 93                                          NaN
# 95                                          NaN
# 96                                          NaN
# 99                                          NaN
# 101                                         NaN
#
#     is 'survey tf result (%)' missing?_from_country  \
# 3                                               NaN
# 10                                              NaN
# 14                                              NaN
# 16                                              NaN
# 20                                              NaN
# 23                                              NaN
# 31                                              NaN
# 36                                              NaN
# 41                                              NaN
# 48                                              NaN
# 51                                              NaN
# 54                                              NaN
# 55                                              NaN
# 64                                              NaN
# 66                                              NaN
# 69                                              NaN
# 85                                              NaN
# 86                                              NaN
# 88                                              NaN
# 90                                              NaN
# 93                                              NaN
# 95                                              NaN
# 96                                              NaN
# 99                                              NaN
# 101                                             NaN
#
#     is 'survey tt result (%)' missing?_from_nis  \
# 3                                           NaN
# 10                                          NaN
# 14                                          NaN
# 16                                          NaN
# 20                                          NaN
# 23                                          NaN
# 31                                          NaN
# 36                                          NaN
# 41                                          NaN
# 48                                          NaN
# 51                                          NaN
# 54                                          NaN
# 55                                          NaN
# 64                                          NaN
# 66                                          NaN
# 69                                          NaN
# 85                                          NaN
# 86                                          NaN
# 88                                          NaN
# 90                                          NaN
# 93                                          NaN
# 95                                          NaN
# 96                                          NaN
# 99                                          NaN
# 101                                         NaN
#
#     is 'survey tt result (%)' missing?_from_country
# 3                                               NaN
# 10                                              NaN
# 14                                              NaN
# 16                                              NaN
# 20                                              NaN
# 23                                              NaN
# 31                                              NaN
# 36                                              NaN
# 41                                              NaN
# 48                                              NaN
# 51                                              NaN
# 54                                              NaN
# 55                                              NaN
# 64                                              NaN
# 66                                              NaN
# 69                                              NaN
# 85                                              NaN
# 86                                              NaN
# 88                                              NaN
# 90                                              NaN
# 93                                              NaN
# 95                                              NaN
# 96                                              NaN
# 99                                              NaN
# 101                                             NaN
#
# [25 rows x 142 columns]

# %% [markdown]
# ### Write Additions and Deletions to Excel File

# %%
#Matches on EU/UID
from_nis_EU_uid_new = compare_EU_uid.df1_unq_rows
from_country_EU_uid_new = compare_EU_uid.df2_unq_rows

#Matches on EU/FY
from_nis_EU_FY_new = compare_EU_FY.df1_unq_rows
from_country_EU_FY_new = compare_EU_FY.df2_unq_rows

#Export to Excel
writer = pd.ExcelWriter(additions_deletions, engine='xlsxwriter')
from_country_EU_uid_new.to_excel(writer, sheet_name = "From Country_EU_UID", index=False)
from_nis_EU_uid_new.to_excel(writer, sheet_name="From NIS_EU_UID", index=False)


writer.close()
